# %% [markdown]
# # Image Classification with CNN - LeNet5 architecture

# %% [markdown]
# In this exercise, we will apply the LeNet5 algorithm to the Fashion MNIST dataset and improve your performances.

# %% [markdown]
# We will first download the data:

# %%
# TODO: Load the dataset
from tensorflow.keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# # # If your computer is slow, try to use a subset of data, e.g.
# X_train = X_train[:10000]
# y_train = y_train[:10000]
# X_test = X_test[:2000]
# y_test = y_test[:2000]
X_train.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28)

# %% [markdown]
# As you already know, this dataset contains 10 classes:
# * 0:	T-shirt/top
# * 1:	Trouser
# * 2:	Pullover
# * 3:	Dress
# * 4:	Coat
# * 5:	Sandal
# * 6:	Shirt
# * 7:	Sneaker
# * 8:	Bag
# * 9:	Ankle boot

# %% [markdown]
# You can have a look at some images if needed, even if you already know them.

# %%
# TODO: Explore the data, display some input images
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

label_class = ['top', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

idx = np.random.randint(X_train.shape[0])

plt.imshow(X_train[idx], cmap='gray_r')
plt.title(label_class[y_train[idx]])
plt.show()

# %% [markdown]
# Make the data preparation and preprocessing: scale and reshape the data, put the labels to the good shape.

# %%
# TODO: Make the data preparation
from tensorflow.keras.utils import to_categorical

y_train_cat = to_categorical(y_train,num_classes = 10)
y_test_cat = to_categorical(y_test,num_classes = 10)


X_train_norm = X_train/255
X_test_norm = X_test/255

X_train_norm = X_train_norm.reshape(X_train_norm.shape[0], 28, 28, 1)
X_test_norm = X_test_norm.reshape(X_test_norm.shape[0], 28, 28, 1)

X_train_norm.shape #Should be (60000, 28, 28, 1)
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# Now build the LeNet5 architecture. You can reuse the one of the course, or try to build it by yourself.
#
# The architecture is the following:
#
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1WteTU2FPIVMkBKmMxGpFm5OjsX-szTbB">
# </p>

# %%
# TODO: Build your model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, Conv2D, Flatten, Dense


def lenet5():

    model = Sequential()

    # Layer C1
    model.add(Conv2D(filters=6, name='C1', kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
    # Layer S2
    model.add(MaxPooling2D(pool_size=(2, 2), name='S2'))
    # Layer C3
    model.add(Conv2D(filters=16, name='C3', kernel_size=(3, 3), activation='relu'))
    # Layer S4
    model.add(MaxPooling2D(pool_size=(2, 2), name='S4'))
    # Before going into layer C5, we flatten our units
    model.add(Flatten())
    # Layer C5
    model.add(Dense(120, activation='relu', name='C5'))
    # Layer F6
    model.add(Dense(84, activation='relu', name='F5'))
    # Output layer
    model.add(Dense(units=10, activation = 'softmax'))

    return model

lenet5().summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ C1 (Conv2D)                     │ (None, 26, 26, 6)      │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ S2 (MaxPooling2D)               │ (None, 13, 13, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ C3 (Conv2D)                     │ (None, 11, 11, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ S4 (MaxPooling2D)               │ (None, 5, 5, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ C5 (Dense)                      │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ F5 (Dense)                      │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,074 (234.66 KB)
#  Trainable params: 60,074 (234.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Now compile and fit your model on your training data. Since this is a multiclass classification, the loss is not `binary_crossentropy` anymore, but `categorical_crossentropy`.

# %%
# TODO: Compile and fit your model
import os

# os.environ['KMP_DUPLICATE_LIB_OK']='True' #https://stackoverflow.com/questions/53014306/error-15-initializing-libiomp5-dylib-but-found-libiomp5-dylib-already-initial


from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import TensorBoard

model = lenet5()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define now our callbacks
# callbacks = [EarlyStopping(monitor='val_loss', patience=10), TensorBoard(log_dir='./keras-logs', histogram_freq=0, write_graph=True, write_images=True)]
callbacks = [EarlyStopping(monitor='val_loss', patience=10)]

# Finally fit the model
model.fit(x=X_train_norm, y=y_train_cat, validation_data=(X_test_norm, y_test_cat), epochs=100, batch_size=2048, callbacks=callbacks)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.3512 - loss: 2.0768 - val_accuracy: 0.6828 - val_loss: 0.9632
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7062 - loss: 0.8297 - val_accuracy: 0.7505 - val_loss: 0.6786
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7584 - loss: 0.6326 - val_accuracy: 0.7774 - val_loss: 0.5939
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7920 - loss: 0.5536 - val_accuracy: 0.7909 - val_loss: 0.5502
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8066 - loss: 0.5167 - val_accuracy: 0.8150 - val_loss: 0.5064
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8278 - loss: 0.4719 - val_accuracy: 0.8257 - val_loss: 0.4788
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8384 - loss: 0.4486 - val_accuracy: 0.8311 - val_loss: 0.4579
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8424 - loss: 0.4334 - val_accuracy: 0.8417 - val_loss: 0.4419
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8506 - loss: 0.4176 - val_accuracy: 0.8413 - val_loss: 0.4375
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8548 - loss: 0.4041 - val_accuracy: 0.8450 - val_loss: 0.4263
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8562 - loss: 0.3982 - val_accuracy: 0.8524 - val_loss: 0.4087
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8660 - loss: 0.3768 - val_accuracy: 0.8547 - val_loss: 0.4099
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8665 - loss: 0.3736 - val_accuracy: 0.8555 - val_loss: 0.3974
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8698 - loss: 0.3625 - val_accuracy: 0.8587 - val_loss: 0.3959
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8702 - loss: 0.3626 - val_accuracy: 0.8623 - val_loss: 0.3833
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8760 - loss: 0.3455 - val_accuracy: 0.8612 - val_loss: 0.3803
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8768 - loss: 0.3457 - val_accuracy: 0.8609 - val_loss: 0.3812
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8773 - loss: 0.3419 - val_accuracy: 0.8656 - val_loss: 0.3743
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8801 - loss: 0.3310 - val_accuracy: 0.8676 - val_loss: 0.3686
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8805 - loss: 0.3296 - val_accuracy: 0.8682 - val_loss: 0.3656
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8794 - loss: 0.3325 - val_accuracy: 0.8725 - val_loss: 0.3576
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8855 - loss: 0.3172 - val_accuracy: 0.8717 - val_loss: 0.3563
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8844 - loss: 0.3169 - val_accuracy: 0.8718 - val_loss: 0.3524
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.
100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9261 - loss: 0.2030 - val_accuracy: 0.8976 - val_loss: 0.2910
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9244 - loss: 0.2028 - val_accuracy: 0.8935 - val_loss: 0.2963
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9245 - loss: 0.2040 - val_accuracy: 0.8964 - val_loss: 0.2915
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9265 - loss: 0.2000 - val_accuracy: 0.8972 - val_loss: 0.2931
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9269 - loss: 0.1999 - val_accuracy: 0.8949 - val_loss: 0.2987
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9265 - loss: 0.1995 - val_accuracy: 0.8967 - val_loss: 0.2959
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9268 - loss: 0.1993 - val_accuracy: 0.8970 - val_loss: 0.2952
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9265 - loss: 0.1959 - val_accuracy: 0.8928 - val_loss: 0.3040
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9254 - loss: 0.2010 - val_accuracy: 0.8956 - val_loss: 0.3010
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9271 - loss: 0.1981 - val_accuracy: 0.8963 - val_loss: 0.2930
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9281 - loss: 0.1964 - val_accuracy: 0.8979 - val_loss: 0.2955

# %% [markdown]
# Have a look at the tensorboard and see if it gives a deeper understanding of your model.

# %% [markdown]
# Compute then the accuracy of your model. Is it better than a regular MLP used before?

# %%
# TODO: Compute the accuracy of your model
from sklearn.metrics import accuracy_score

batch_size = 1024
y_pred_train = to_categorical(model.predict(X_train_norm, batch_size=batch_size).argmax(axis=1), num_classes=10)
y_pred_test = to_categorical(model.predict(X_test_norm, batch_size=batch_size).argmax(axis=1), num_classes=10)

print('accuracy on train with NN:', accuracy_score(y_pred_train, y_train_cat))
print('accuracy on test with NN:', accuracy_score(y_pred_test, y_test_cat))

# with 20 epoch, accuracy on train with CNN: 0.8712333333333
# with 20 epoch, accuracy on test with CNN: 0.8573
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# accuracy on train with NN: 0.9298166666666666
# accuracy on test with NN: 0.8979

# %% [markdown]
# We will now add image augmentation to improve our results, especially we will try to reduce overfitting this way.
#
# To do so, you can use `ImageDataGenerator` from Keras that makes all the work for you (including rescaling), with the following parameter:
# * `horizontal_flip=True`
#
# For more info about how the `ImageDataGenerator` works, you can check out [this article](https://www.pyimagesearch.com/2019/07/08/keras-imagedatagenerator-and-data-augmentation/).
#
# Begin by creating an object `ImageDataGenerator` with this parameter.

# %%
# TODO: Instantiate an ImageDataGenerator object
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(horizontal_flip=True)

# %% [markdown]
# Finally, you can train your model using this generator, with the method `fit_generator` of your model and the method `flow` of your `ImageDataGenerator`.

# %%
# TODO: train your model
batch_size = 1024
model.fit(datagen.flow(X_train_norm, y_train_cat, batch_size=batch_size),
          validation_data=(X_test_norm, y_test_cat),
          callbacks=callbacks,
          steps_per_epoch=len(X_train_norm) // batch_size,
          epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.8376 - loss: 0.6379 - val_accuracy: 0.8867 - val_loss: 0.3186
# Epoch 2/100
#  1/58 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8955 - loss: 0.3030
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8955 - loss: 0.3030 - val_accuracy: 0.8873 - val_loss: 0.3133
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.8976 - loss: 0.2881 - val_accuracy: 0.8905 - val_loss: 0.3047
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.
100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 0.9170 - loss: 0.2211 - val_accuracy: 0.8984 - val_loss: 0.2805
# Epoch 36/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9238 - loss: 0.2041 - val_accuracy: 0.9012 - val_loss: 0.2781
# Epoch 37/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.9243 - loss: 0.2088 - val_accuracy: 0.8990 - val_loss: 0.2807
# Epoch 38/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9209 - loss: 0.2119 - val_accuracy: 0.8998 - val_loss: 0.2816
# Epoch 39/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9211 - loss: 0.2150 - val_accuracy: 0.8970 - val_loss: 0.2873
# Epoch 40/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9326 - loss: 0.1788 - val_accuracy: 0.8981 - val_loss: 0.2862
# Epoch 41/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9219 - loss: 0.2083 - val_accuracy: 0.8987 - val_loss: 0.2865
# Epoch 42/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9082 - loss: 0.2311 - val_accuracy: 0.9006 - val_loss: 0.2773
# Epoch 43/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9231 - loss: 0.2085 - val_accuracy: 0.8989 - val_loss: 0.2918
# Epoch 44/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9316 - loss: 0.1911 - val_accuracy: 0.8980 - val_loss: 0.2952
# Epoch 45/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9240 - loss: 0.2065 - val_accuracy: 0.8984 - val_loss: 0.2804
# Epoch 46/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9248 - loss: 0.2016 - val_accuracy: 0.8974 - val_loss: 0.2816
# Epoch 47/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.9235 - loss: 0.2071 - val_accuracy: 0.9033 - val_loss: 0.2755
# Epoch 48/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9219 - loss: 0.2197 - val_accuracy: 0.9007 - val_loss: 0.2817
# Epoch 49/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.9242 - loss: 0.2051 - val_accuracy: 0.8989 - val_loss: 0.2899
# Epoch 50/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8926 - loss: 0.2616 - val_accuracy: 0.9036 - val_loss: 0.2792
# Epoch 51/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9253 - loss: 0.2025 - val_accuracy: 0.8937 - val_loss: 0.3028
# Epoch 52/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9014 - loss: 0.2465 - val_accuracy: 0.9001 - val_loss: 0.2894
# Epoch 53/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9243 - loss: 0.2052 - val_accuracy: 0.9035 - val_loss: 0.2786
# Epoch 54/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9219 - loss: 0.1960 - val_accuracy: 0.9032 - val_loss: 0.2796
# Epoch 55/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9250 - loss: 0.2015 - val_accuracy: 0.9037 - val_loss: 0.2761
# Epoch 56/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9326 - loss: 0.2033 - val_accuracy: 0.9039 - val_loss: 0.2774
# Epoch 57/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9252 - loss: 0.1988 - val_accuracy: 0.9008 - val_loss: 0.2820

# %% [markdown]
# Recompute the accuracy of your model, does it improve your performances with data augmentation?

# %%
# TODO: Compute the accuracy of your model
from sklearn.metrics import accuracy_score

batch_size=1024
y_pred_train = to_categorical(model.predict(X_train_norm, batch_size=batch_size).argmax(axis=1), num_classes=10)
y_pred_test = to_categorical(model.predict(X_test_norm, batch_size=batch_size).argmax(axis=1), num_classes=10)

print('accuracy on train with CNN:', accuracy_score(y_pred_train, y_train_cat))
print('accuracy on test with CNN:', accuracy_score(y_pred_test, y_test_cat))
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# accuracy on train with CNN: 0.9353666666666667
# accuracy on test with CNN: 0.9008

# %% [markdown]
# You can now try to improve even more your results. For example, add more parameters to your `ImageDataGenerator`, play with some hyperparameters, and so on...
